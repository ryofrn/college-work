# %% [markdown]
# #PanDas Week 2

# %% [markdown]
# # #05 Membalik Urutan Baris dan Kolom pada Data Frame
# Import Modules

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 1.3.5
# 1.21.6

# %% [markdown]
# Persiapan Data Frame

# %%
n_rows = 5
n_cols = 5
cols = tuple('ABCDE')

df = pd.DataFrame(np.random.randint(1, 10, size=(n_rows, n_cols)), columns=cols)
df
# Out:
#    A  B  C  D  E
# 0  5  4  9  9  1
# 1  8  2  8  8  4
# 2  9  1  7  9  7
# 3  1  6  9  8  6
# 4  4  7  8  2  7

# %% [markdown]
# Membalik Urutan Kolom

# %%
df.loc[:, ::-1]
# Out:
#    E  D  C  B  A
# 0  1  9  9  4  5
# 1  4  8  8  2  8
# 2  7  9  7  1  9
# 3  6  8  9  6  1
# 4  7  2  8  7  4

# %% [markdown]
# Membalik Urutan Baris

# %%
df.loc[::-1]
# Out:
#    A  B  C  D  E
# 4  4  7  8  2  7
# 3  1  6  9  8  6
# 2  9  1  7  9  7
# 1  8  2  8  8  4
# 0  5  4  9  9  1

# %% [markdown]
# Membalik Urutan Baris dan Melakukan Penyesuaian Ulang Index

# %%
df.loc[::-1].reset_index(drop=True)
# Out:
#    A  B  C  D  E
# 0  4  7  8  2  7
# 1  1  6  9  8  6
# 2  9  1  7  9  7
# 3  8  2  8  8  4
# 4  5  4  9  9  1

# %% [markdown]
# # #06 Mengganti Nama (label) Kolom pada Data Frame
# Import Modules

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 1.3.5
# 1.21.6

# %% [markdown]
# Persiapan Data Frame

# %%
n_rows = 5
n_cols = 5
cols = tuple('ABCDE')

df = pd.DataFrame(np.random.randint(1, 10, size=(n_rows, n_cols)), columns=cols)
df
# Out:
#    A  B  C  D  E
# 0  1  6  3  5  7
# 1  6  8  3  1  2
# 2  2  6  1  6  8
# 3  9  3  4  1  9
# 4  7  1  9  3  4

# %% [markdown]
# Mengganti Nama (label) Untuk Sebuah Kolom pada Data Frame

# %%
df.rename(columns={'C':'Hobi'})
# Out:
#    A  B  Hobi  D  E
# 0  1  6     3  5  7
# 1  6  8     3  1  2
# 2  2  6     1  6  8
# 3  9  3     4  1  9
# 4  7  1     9  3  4

# %% [markdown]
# Mengganti Nama (label) Untuk Banyak Kolom pada Data Frame

# %%
df.rename(columns={'A':'Nama', 'B':'Alamat', 'D':'Kota'})
# Out:
#    Nama  Alamat  C  Kota  E
# 0     1       6  3     5  7
# 1     6       8  3     1  2
# 2     2       6  1     6  8
# 3     9       3  4     1  9
# 4     7       1  9     3  4

# %% [markdown]
# # #07 Menghapus (drop) Missing Values (NaN) pada Data Frame
# Import Modules

# %%
import pandas as pd

print(pd.__version__)
# Out:
# 1.3.5

# %% [markdown]
# Persiapan Data Frame

# %%
df = pd.util.testing.makeMissingDataframe().reset_index() 
df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/__init__.py:15: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing
#         index         A         B         C         D
# 0  uZxZboi0Hq -0.588363 -0.162944  0.441149  0.273888
# 1  R3aqXDTOP8       NaN       NaN -0.684160  0.555466
# 2  Eje4OrAtWe  0.792983  0.691138       NaN  0.396113
# 3  YFSdgswzoS  0.975577  1.763194       NaN  0.711088
# 4  aSU8IgAW1w  1.827981  0.528231 -0.365139  0.008549

# %%
df = df.rename(columns={'index':'Z'})
df.head()
# Out:
#             Z         A         B         C         D
# 0  uZxZboi0Hq -0.588363 -0.162944  0.441149  0.273888
# 1  R3aqXDTOP8       NaN       NaN -0.684160  0.555466
# 2  Eje4OrAtWe  0.792983  0.691138       NaN  0.396113
# 3  YFSdgswzoS  0.975577  1.763194       NaN  0.711088
# 4  aSU8IgAW1w  1.827981  0.528231 -0.365139  0.008549

# %%
df_backup = df.copy(deep=True)

# %% [markdown]
# Menghapus (drop) Setiap Kolom yang Mengandung Missing Values

# %%
df = df.dropna(axis='columns') 
df.head()
# Out:
#             Z
# 0  uZxZboi0Hq
# 1  R3aqXDTOP8
# 2  Eje4OrAtWe
# 3  YFSdgswzoS
# 4  aSU8IgAW1w

# %% [markdown]
# Menghapus (drop) Setiap Baris yang Mengandung Missing Values

# %%
df = df_backup.copy(deep=True)

df = df.dropna(axis='rows')

df.head()
# Out:
#             Z         A         B         C         D
# 0  uZxZboi0Hq -0.588363 -0.162944  0.441149  0.273888
# 4  aSU8IgAW1w  1.827981  0.528231 -0.365139  0.008549
# 7  UfoFY6V7dM  0.669411  0.375683  0.378631 -1.152524
# 8  e1YVVtdDnW -0.139155  1.187161 -1.413395  0.667771
# 9  Al3nhPdaFg  0.313838  0.621274 -0.226896 -0.235325

# %% [markdown]
# Persentase missing values untuk tiap kolom

# %%
df = df_backup.copy(deep=True)

df.isna().mean()*100
# Out:
# Z     0.000000
# A    13.333333
# B    10.000000
# C     6.666667
# D    10.000000
# dtype: float64

# %% [markdown]
# Menghapus (drop) Setiap Kolom yang Mengandung Missing Values Berdasarkan Threshold (ambang batas)

# %%
treshold = len(df) * 0.9 
df = df.dropna(thresh=treshold, axis='columns')
df.head()
# Out:
#             Z         B         C         D
# 0  uZxZboi0Hq -0.162944  0.441149  0.273888
# 1  R3aqXDTOP8       NaN -0.684160  0.555466
# 2  Eje4OrAtWe  0.691138       NaN  0.396113
# 3  YFSdgswzoS  1.763194       NaN  0.711088
# 4  aSU8IgAW1w  0.528231 -0.365139  0.008549

# %% [markdown]
# # #08 Memeriksa Kesamaan Antar Dua Buah Kolom (Series) pada Data Frame
# Import Modules

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 1.3.5
# 1.21.6

# %% [markdown]
# Persiapan Data Frame

# %%
data = {'A':[15, 15, 18, np.nan, 12], 
        'B':[15, 15, 18, np.nan, 12]}

df = pd.DataFrame(data)
df
# Out:
#       A     B
# 0  15.0  15.0
# 1  15.0  15.0
# 2  18.0  18.0
# 3   NaN   NaN
# 4  12.0  12.0

# %% [markdown]
# Mengenal Pandas Series
#
# - Series adalah struktur data lain yang dimiliki pandas dengan objek 1-dimensi yang berisi sequence nilai dan berasosiasi dengan label data, yang disebut indeks.
# - Untuk membuat sebuah Series atau kolom, kita bisa membuatnya dari sebuah array dengan memanggil fungsi Series pada pandas.

# %%
df['A']
# Out:
# 0    15.0
# 1    15.0
# 2    18.0
# 3     NaN
# 4    12.0
# Name: A, dtype: float64

# %%
type(df['A'])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Memeriksa Kesamaan dengan Operator ==

# %%
df['A'] == df['B']
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# dtype: bool

# %% [markdown]
# Memeriksa kesamaan dengan method equals()

# %%
df['A'].equals(df['B'])
# Out:
# True

# %% [markdown]
# Memeriksa Kesamaan Antar Dua Data Frame

# %%
df1 = df.copy(deep=True)

df.equals(df1)
# Out:
# True

# %%
df == df1
# Out:
#        A      B
# 0   True   True
# 1   True   True
# 2   True   True
# 3  False  False
# 4   True   True
